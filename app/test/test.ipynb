# %% [markdown]
# Test of DB connection

# %%
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
DB_USER = "root"
DB_PASSWORD = "Gayuth12345!"
DB_HOST = "localhost"
DB_PORT = "3306"
DB_NAME = "rental_db"

DATABASE_URL = (
    f"mysql+pymysql://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

engine = create_engine(DATABASE_URL)
engine.connect()

# %%
inspector = inspect(engine)

tables = inspector.get_table_names()
tables
# Out:
# ['listing', 'listing_image', 'seller', 'verification_code']

# %%
schema_info = {}

for table in tables:
    columns = inspector.get_columns(table)
    schema_info[table] = [
        {
            "name": col["name"],
            "type": str(col["type"])
        }
        for col in columns
    ]

schema_info
# Out:
# {'listing': [{'name': 'listing_id', 'type': 'BIGINT'},
#   {'name': 'title', 'type': 'VARCHAR(255)'},
#   {'name': 'location', 'type': 'VARCHAR(255)'},
#   {'name': 'address', 'type': 'VARCHAR(255)'},
#   {'name': 'about', 'type': 'VARCHAR(255)'},
#   {'name': 'price', 'type': 'DOUBLE'},
#   {'name': 'bedrooms', 'type': 'INTEGER'},
#   {'name': 'bathrooms', 'type': 'INTEGER'},
#   {'name': 'guests', 'type': 'INTEGER'},
#   {'name': 'property_type', 'type': 'ENUM'},
#   {'name': 'seller_id', 'type': 'BIGINT'}],
#  'listing_image': [{'name': 'image_id', 'type': 'BIGINT'},
#   {'name': 'listing_id', 'type': 'BIGINT'},
#   {'name': 'url', 'type': 'VARCHAR(500)'},
#   {'name': 'alt_text', 'type': 'VARCHAR(255)'}],
#  'seller': [{'name': 'seller_id', 'type': 'BIGINT'},
#   {'name': 'owner_fname', 'type': 'VARCHAR(255)'},
#   {'name': 'owner_lname', 'type': 'VARCHAR(255)'},
#   {'name': 'phone', 'type': 'VARCHAR(255)'},
#   {'name': 'email', 'type': 'VARCHAR(255)'},
# ...

# %%
pd.read_sql("SELECT * FROM listing LIMIT 5;", engine)
# Out:
#    listing_id                          title location  \
# 0          16     Modern Duplex with Balcony  Colombo
# 1          17  Cozy Single Bedroom Apartment  Colombo
# 2          18      Spacious Family Apartment  Colombo
# 3          19       Shared Room for Students  Colombo
# 4          21                            123      123
#
#                           address  \
# 0  22 Ocean Boulevard, Colombo 05
# 1      15 Palm Street, Colombo 03
# 2   8 Ocean View Lane, Colombo 04
# 3      5 College Road, Colombo 06
# 4                             123
#
#                                                about     price  bedrooms  \
# 0  Stylish duplex apartment with a private balcon...   85000.0         2
# 1  A comfortable single bedroom apartment ideal f...   55000.0         1
# 2  Large apartment with 3 bedrooms and a scenic c...  120000.0         3
# 3  Affordable shared room for students with all b...   30000.0         1
# ...

# %%
import sys
from pathlib import Path

# Add project root (one folder above 'app') to Python path
project_root = Path.cwd().parent.parent  # adjust if notebook is inside another folder
sys.path.append(str(project_root))
print(project_root)
# Out:
# c:\Users\Gayuth\Documents\Programming\Full Stack\RentalApplication\renting-app-nltosql

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
llm.invoke("How are you").content
# Out:
# "I'm just a computer program, so I don't have feelings, but I'm here and ready to help you! How can I assist you today?"

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

TABLE_SELECTION_PROMPT = PromptTemplate(
    input_variables=["question", "tables"],
    template="""
You are a database expert.

Available tables:
{tables}

Based on the user's question, return a comma-separated list of tables
that are required to answer the question.

User question:
{question}

Only return table names. No explanations.
"""
)

llm = ChatOpenAI(model="gpt-4o-mini")

def select_tables(question: str, available_tables: list[str]) -> list[str]:
  prompt = TABLE_SELECTION_PROMPT.format(
    question=question,
    tables=", ".join(available_tables)
  )

  response = llm.invoke(prompt).content
  return [t.strip() for t in response.split(",")]

# %%
# from app.chains.table_selector import select_tables

TABLES = ["listing", "location", "user", "booking"]

question = "Show me all listings under 50,000 LKR"

tables = select_tables(question, TABLES)
tables
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 7
#       3 TABLES = ["listing", "location", "user", "booking"]
#       5 question = "Show me all listings under 50,000 LKR"
# ----> 7 tables = select_tables(question, TABLES)
#       8 tables
#
# Cell In[12], line 30, in select_tables(question, available_tables)
#      24 def select_tables(question: str, available_tables: list[str]) -> list[str]:
#      25   prompt = TABLE_SELECTION_PROMPT.format(
#      26     question=question,
#      27     tables=", ".join(available_tables)
#      28   )
# ---> 30   response = llm.invoke(prompt).content
#      31   return [t.strip() for t in response.split(",")]
#
# ...
